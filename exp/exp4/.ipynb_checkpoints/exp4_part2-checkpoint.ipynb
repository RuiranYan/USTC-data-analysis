# %%
import numpy as np
import json
import lightgbm as lgb
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
import matplotlib.pylab as plt

# %%
data = pd.read_csv('exp3.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 81 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  80000 non-null  int64
#  1   queueId                80000 non-null  int64
#  2   mapId                  80000 non-null  int64
#  3   seasonId               80000 non-null  int64
#  4   team1_win              80000 non-null  int64
#  5   team1_firstBlood       80000 non-null  bool
#  6   team1_firstTower       80000 non-null  bool
#  7   team1_firstInhibitor   80000 non-null  bool
#  8   team1_firstBaron       80000 non-null  bool
#  9   team1_firstDragon      80000 non-null  bool
#  10  team1_firstRiftHerald  80000 non-null  bool
#  11  player1_championId     80000 non-null  int64
#  12  player1_kills          80000 non-null  int64
#  13  player1_deaths         80000 non-null  int64
#  14  player1_assists        80000 non-null  int64
#  15  player1_goldEarned     80000 non-null  int64
#  16  player1_role           80000 non-null  object
#  17  player1_lane           80000 non-null  object
#  18  player2_championId     80000 non-null  int64
#  19  player2_kills          80000 non-null  int64
#  20  player2_deaths         80000 non-null  int64
#  21  player2_assists        80000 non-null  int64
#  22  player2_goldEarned     80000 non-null  int64
#  23  player2_role           80000 non-null  object
#  24  player2_lane           80000 non-null  object
#  25  player3_championId     80000 non-null  int64
#  26  player3_kills          80000 non-null  int64
#  27  player3_deaths         80000 non-null  int64
#  28  player3_assists        80000 non-null  int64
#  29  player3_goldEarned     80000 non-null  int64
#  30  player3_role           80000 non-null  object
#  31  player3_lane           80000 non-null  object
#  32  player4_championId     80000 non-null  int64
#  33  player4_kills          80000 non-null  int64
#  34  player4_deaths         80000 non-null  int64
#  35  player4_assists        80000 non-null  int64
#  36  player4_goldEarned     80000 non-null  int64
#  37  player4_role           80000 non-null  object
#  38  player4_lane           80000 non-null  object
#  39  player5_championId     80000 non-null  int64
#  40  player5_kills          80000 non-null  int64
#  41  player5_deaths         80000 non-null  int64
#  42  player5_assists        80000 non-null  int64
#  43  player5_goldEarned     80000 non-null  int64
#  44  player5_role           80000 non-null  object
#  45  player5_lane           80000 non-null  object
#  46  player6_championId     80000 non-null  int64
#  47  player6_kills          80000 non-null  int64
#  48  player6_deaths         80000 non-null  int64
#  49  player6_assists        80000 non-null  int64
#  50  player6_goldEarned     80000 non-null  int64
#  51  player6_role           80000 non-null  object
#  52  player6_lane           80000 non-null  object
#  53  player7_championId     80000 non-null  int64
#  54  player7_kills          80000 non-null  int64
#  55  player7_deaths         80000 non-null  int64
#  56  player7_assists        80000 non-null  int64
#  57  player7_goldEarned     80000 non-null  int64
#  58  player7_role           80000 non-null  object
#  59  player7_lane           80000 non-null  object
#  60  player8_championId     80000 non-null  int64
#  61  player8_kills          80000 non-null  int64
#  62  player8_deaths         80000 non-null  int64
#  63  player8_assists        80000 non-null  int64
#  64  player8_goldEarned     80000 non-null  int64
#  65  player8_role           80000 non-null  object
#  66  player8_lane           80000 non-null  object
#  67  player9_championId     80000 non-null  int64
#  68  player9_kills          80000 non-null  int64
#  69  player9_deaths         80000 non-null  int64
#  70  player9_assists        80000 non-null  int64
#  71  player9_goldEarned     80000 non-null  int64
#  72  player9_role           80000 non-null  object
#  73  player9_lane           80000 non-null  object
#  74  player10_championId    80000 non-null  int64
#  75  player10_kills         80000 non-null  int64
#  76  player10_deaths        80000 non-null  int64
#  77  player10_assists       80000 non-null  int64
#  78  player10_goldEarned    80000 non-null  int64
#  79  player10_role          80000 non-null  object
#  80  player10_lane          80000 non-null  object
# dtypes: bool(6), int64(55), object(20)
# memory usage: 46.2+ MB

# %%
data.head()
# Out:
#    index  queueId  mapId  seasonId  team1_win  team1_firstBlood  \
# 0      0      420     11        13          0              True
# 1      1      420     11        13          1             False
# 2      2      420     11        13          0             False
# 3      3      420     11        13          0              True
# 4      4      420     11        13          1              True
#
#    team1_firstTower  team1_firstInhibitor  team1_firstBaron  \
# 0             False                 False             False
# 1              True                  True             False
# 2              True                 False             False
# 3             False                 False             False
# 4              True                  True             False
#
#    team1_firstDragon  ...  player9_goldEarned  player9_role  player9_lane  \
# 0              False  ...                6967   DUO_SUPPORT          NONE
# 1               True  ...                8133          SOLO        MIDDLE
# 2               True  ...               11868     DUO_CARRY        BOTTOM
# 3               True  ...                6703   DUO_SUPPORT        BOTTOM
# 4              False  ...                6823           DUO        MIDDLE
#
#    player10_championId  player10_kills  player10_deaths player10_assists  \
# 0                  157               3                0                8
# 1                  555               3                7                4
# 2                  122               2                2                1
# 3                   23               6                2               10
# 4                   25               5                7                8
#
#   player10_goldEarned  player10_role  player10_lane
# 0                8168            DUO           NONE
# 1                6943    DUO_SUPPORT         BOTTOM
# 2                9685           SOLO            TOP
# 3               13109           SOLO            TOP
# 4                6809    DUO_SUPPORT         BOTTOM
#
# [5 rows x 81 columns]

# %%
data.drop(columns=['index','mapId','seasonId'],axis=1,inplace=True)
data.head()
# Out:
#    queueId  team1_win  team1_firstBlood  team1_firstTower  \
# 0      420          0              True             False
# 1      420          1             False              True
# 2      420          0             False              True
# 3      420          0              True             False
# 4      420          1              True              True
#
#    team1_firstInhibitor  team1_firstBaron  team1_firstDragon  \
# 0                 False             False              False
# 1                  True             False               True
# 2                 False             False               True
# 3                 False             False               True
# 4                  True             False              False
#
#    team1_firstRiftHerald  player1_championId  player1_kills  ...  \
# 0                  False                 107              2  ...
# 1                   True                  76             10  ...
# 2                   True                  51              7  ...
# 3                  False                  28              5  ...
# 4                   True                  79              4  ...
#
#    player9_goldEarned  player9_role  player9_lane player10_championId  \
# 0                6967   DUO_SUPPORT          NONE                 157
# 1                8133          SOLO        MIDDLE                 555
# 2               11868     DUO_CARRY        BOTTOM                 122
# 3                6703   DUO_SUPPORT        BOTTOM                  23
# 4                6823           DUO        MIDDLE                  25
#
#   player10_kills  player10_deaths  player10_assists  player10_goldEarned  \
# 0              3                0                 8                 8168
# 1              3                7                 4                 6943
# 2              2                2                 1                 9685
# 3              6                2                10                13109
# 4              5                7                 8                 6809
#
#    player10_role  player10_lane
# 0            DUO           NONE
# 1    DUO_SUPPORT         BOTTOM
# 2           SOLO            TOP
# 3           SOLO            TOP
# 4    DUO_SUPPORT         BOTTOM
#
# [5 rows x 78 columns]

# %%
data.columns
# Out:
# Index(['queueId', 'team1_win', 'team1_firstBlood', 'team1_firstTower',
#        'team1_firstInhibitor', 'team1_firstBaron', 'team1_firstDragon',
#        'team1_firstRiftHerald', 'player1_championId', 'player1_kills',
#        'player1_deaths', 'player1_assists', 'player1_goldEarned',
#        'player1_role', 'player1_lane', 'player2_championId', 'player2_kills',
#        'player2_deaths', 'player2_assists', 'player2_goldEarned',
#        'player2_role', 'player2_lane', 'player3_championId', 'player3_kills',
#        'player3_deaths', 'player3_assists', 'player3_goldEarned',
#        'player3_role', 'player3_lane', 'player4_championId', 'player4_kills',
#        'player4_deaths', 'player4_assists', 'player4_goldEarned',
#        'player4_role', 'player4_lane', 'player5_championId', 'player5_kills',
#        'player5_deaths', 'player5_assists', 'player5_goldEarned',
#        'player5_role', 'player5_lane', 'player6_championId', 'player6_kills',
#        'player6_deaths', 'player6_assists', 'player6_goldEarned',
#        'player6_role', 'player6_lane', 'player7_championId', 'player7_kills',
#        'player7_deaths', 'player7_assists', 'player7_goldEarned',
#        'player7_role', 'player7_lane', 'player8_championId', 'player8_kills',
#        'player8_deaths', 'player8_assists', 'player8_goldEarned',
#        'player8_role', 'player8_lane', 'player9_championId', 'player9_kills',
#        'player9_deaths', 'player9_assists', 'player9_goldEarned',
#        'player9_role', 'player9_lane', 'player10_championId', 'player10_kills',
#        'player10_deaths', 'player10_assists', 'player10_goldEarned',
#        'player10_role', 'player10_lane'],
#       dtype='object')

# %%
for index in data.columns:
    if 'Id' in index:
        data[index] = data[index].astype('object')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 78 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   queueId                80000 non-null  object
#  1   team1_win              80000 non-null  int64
#  2   team1_firstBlood       80000 non-null  bool
#  3   team1_firstTower       80000 non-null  bool
#  4   team1_firstInhibitor   80000 non-null  bool
#  5   team1_firstBaron       80000 non-null  bool
#  6   team1_firstDragon      80000 non-null  bool
#  7   team1_firstRiftHerald  80000 non-null  bool
#  8   player1_championId     80000 non-null  object
#  9   player1_kills          80000 non-null  int64
#  10  player1_deaths         80000 non-null  int64
#  11  player1_assists        80000 non-null  int64
#  12  player1_goldEarned     80000 non-null  int64
#  13  player1_role           80000 non-null  object
#  14  player1_lane           80000 non-null  object
#  15  player2_championId     80000 non-null  object
#  16  player2_kills          80000 non-null  int64
#  17  player2_deaths         80000 non-null  int64
#  18  player2_assists        80000 non-null  int64
#  19  player2_goldEarned     80000 non-null  int64
#  20  player2_role           80000 non-null  object
#  21  player2_lane           80000 non-null  object
#  22  player3_championId     80000 non-null  object
#  23  player3_kills          80000 non-null  int64
#  24  player3_deaths         80000 non-null  int64
#  25  player3_assists        80000 non-null  int64
#  26  player3_goldEarned     80000 non-null  int64
#  27  player3_role           80000 non-null  object
#  28  player3_lane           80000 non-null  object
#  29  player4_championId     80000 non-null  object
#  30  player4_kills          80000 non-null  int64
#  31  player4_deaths         80000 non-null  int64
#  32  player4_assists        80000 non-null  int64
#  33  player4_goldEarned     80000 non-null  int64
#  34  player4_role           80000 non-null  object
#  35  player4_lane           80000 non-null  object
#  36  player5_championId     80000 non-null  object
#  37  player5_kills          80000 non-null  int64
#  38  player5_deaths         80000 non-null  int64
#  39  player5_assists        80000 non-null  int64
#  40  player5_goldEarned     80000 non-null  int64
#  41  player5_role           80000 non-null  object
#  42  player5_lane           80000 non-null  object
#  43  player6_championId     80000 non-null  object
#  44  player6_kills          80000 non-null  int64
#  45  player6_deaths         80000 non-null  int64
#  46  player6_assists        80000 non-null  int64
#  47  player6_goldEarned     80000 non-null  int64
#  48  player6_role           80000 non-null  object
#  49  player6_lane           80000 non-null  object
#  50  player7_championId     80000 non-null  object
#  51  player7_kills          80000 non-null  int64
#  52  player7_deaths         80000 non-null  int64
#  53  player7_assists        80000 non-null  int64
#  54  player7_goldEarned     80000 non-null  int64
#  55  player7_role           80000 non-null  object
#  56  player7_lane           80000 non-null  object
#  57  player8_championId     80000 non-null  object
#  58  player8_kills          80000 non-null  int64
#  59  player8_deaths         80000 non-null  int64
#  60  player8_assists        80000 non-null  int64
#  61  player8_goldEarned     80000 non-null  int64
#  62  player8_role           80000 non-null  object
#  63  player8_lane           80000 non-null  object
#  64  player9_championId     80000 non-null  object
#  65  player9_kills          80000 non-null  int64
#  66  player9_deaths         80000 non-null  int64
#  67  player9_assists        80000 non-null  int64
#  68  player9_goldEarned     80000 non-null  int64
#  69  player9_role           80000 non-null  object
#  70  player9_lane           80000 non-null  object
#  71  player10_championId    80000 non-null  object
#  72  player10_kills         80000 non-null  int64
#  73  player10_deaths        80000 non-null  int64
#  74  player10_assists       80000 non-null  int64
#  75  player10_goldEarned    80000 non-null  int64
#  76  player10_role          80000 non-null  object
#  77  player10_lane          80000 non-null  object
# dtypes: bool(6), int64(41), object(31)
# memory usage: 44.4+ MB

# %%
number_col = [col for col in data.columns if data[col].dtype == 'int64']
category_col = [col for col in data.columns if data[col].dtype != 'int64']
print(len(number_col))
print(len(category_col))
print(number_col)
# Out:
# 41
# 37
# ['team1_win', 'player1_kills', 'player1_deaths', 'player1_assists', 'player1_goldEarned', 'player2_kills', 'player2_deaths', 'player2_assists', 'player2_goldEarned', 'player3_kills', 'player3_deaths', 'player3_assists', 'player3_goldEarned', 'player4_kills', 'player4_deaths', 'player4_assists', 'player4_goldEarned', 'player5_kills', 'player5_deaths', 'player5_assists', 'player5_goldEarned', 'player6_kills', 'player6_deaths', 'player6_assists', 'player6_goldEarned', 'player7_kills', 'player7_deaths', 'player7_assists', 'player7_goldEarned', 'player8_kills', 'player8_deaths', 'player8_assists', 'player8_goldEarned', 'player9_kills', 'player9_deaths', 'player9_assists', 'player9_goldEarned', 'player10_kills', 'player10_deaths', 'player10_assists', 'player10_goldEarned']

# %%
LE = LabelEncoder()
for col in category_col:
    data[col]=LE.fit_transform(data[col])
data.head()
# Out:
#    queueId  team1_win  team1_firstBlood  team1_firstTower  \
# 0        0          0                 1                 0
# 1        0          1                 0                 1
# 2        0          0                 0                 1
# 3        0          0                 1                 0
# 4        0          1                 1                 1
#
#    team1_firstInhibitor  team1_firstBaron  team1_firstDragon  \
# 0                     0                 0                  0
# 1                     1                 0                  1
# 2                     0                 0                  1
# 3                     0                 0                  1
# 4                     1                 0                  0
#
#    team1_firstRiftHerald  player1_championId  player1_kills  ...  \
# 0                      0                  90              2  ...
# 1                      1                  66             10  ...
# 2                      1                  47              7  ...
# 3                      0                  27              5  ...
# 4                      1                  69              4  ...
#
#    player9_goldEarned  player9_role  player9_lane  player10_championId  \
# 0                6967             2             3                  114
# 1                8133             4             2                  146
# 2               11868             1             0                  101
# 3                6703             2             0                   22
# 4                6823             0             2                   24
#
#    player10_kills  player10_deaths  player10_assists  player10_goldEarned  \
# 0               3                0                 8                 8168
# 1               3                7                 4                 6943
# 2               2                2                 1                 9685
# 3               6                2                10                13109
# 4               5                7                 8                 6809
#
#    player10_role  player10_lane
# 0              0              3
# 1              2              0
# 2              4              4
# 3              4              4
# 4              2              0
#
# [5 rows x 78 columns]

# %%
df_label = pd.read_csv('label.csv')
label = df_label['gameDuration'].values
print(label)
# Out:
# [1671 1227 1458 ... 1612 1351 2534]

# %%
# train,test是所有数据的的数据集,label是已知label
train = data.iloc[20000:,:].values
test = data.iloc[:20000,:].values

# %%
from sklearn.model_selection import train_test_split
# 构造训练集和验证集
x_train, x_test, y_train, y_test = train_test_split(train,label,test_size=0.2,shuffle=True)
print(x_train.shape)
print(x_test.shape)
# Out:
# (48000, 78)
# (12000, 78)

# %%
# LGBM简单回归验证测试
LGBMR=lgb.LGBMRegressor()
LGBMR.fit(x_train,y_train)
y_pred = LGBMR.predict(x_test)
print(f'mean square error is :{mean_squared_error(y_test,y_pred)}')
print(f'max error:{max(abs(np.array(y_pred)-np.array(y_test)))}')
# Out:
# mean square error is :4698.696943168427
# max error:445.80549284747303

# %%
# LGBM调参验证测试
evals_result = {}
classfeats = []
for x in category_col:
    classfeats.append(data.columns.get_loc(x))
# print(classfeats)
lgb_train = lgb.Dataset(x_train, y_train)
lgb_eval = lgb.Dataset(x_test, y_test, reference=lgb_train)

params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'mse',
    'max_depth': 15,
    'num_leaves': 20,
    'learning_rate': 0.01,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0,
}

gbm = lgb.train(params,
                lgb_train,
                num_boost_round=8000,
                valid_sets=lgb_eval,
                verbose_eval=50,
                evals_result=evals_result,
                # categorical_feature = classfeats,
                early_stopping_rounds=10)

y_pred = gbm.predict(x_test, num_iteration=gbm.best_iteration)
# 评估
print(f'mean square error is :{mean_squared_error(y_test,y_pred)}')
print(f'max error:{max(abs(np.array(y_pred)-np.array(y_test)))}')
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007348 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's l2: 96233
# [100]	valid_0's l2: 49994.1
# [150]	valid_0's l2: 28798.4
# [200]	valid_0's l2: 18532.7
# [250]	valid_0's l2: 13325.2
# [300]	valid_0's l2: 10487
# [350]	valid_0's l2: 8805.97
# [400]	valid_0's l2: 7736.03
# [450]	valid_0's l2: 7003.01
# [500]	valid_0's l2: 6482.44
# [550]	valid_0's l2: 6089.16
# [600]	valid_0's l2: 5785.45
# [650]	valid_0's l2: 5522.43
# [700]	valid_0's l2: 5306.99
# [750]	valid_0's l2: 5120.74
# [800]	valid_0's l2: 4953.85
# [850]	valid_0's l2: 4813.53
# [900]	valid_0's l2: 4690.82
# [950]	valid_0's l2: 4576.15
# [1000]	valid_0's l2: 4478.52
# [1050]	valid_0's l2: 4390.38
# [1100]	valid_0's l2: 4312.14
# [1150]	valid_0's l2: 4244.59
# [1200]	valid_0's l2: 4183.52
# [1250]	valid_0's l2: 4126.79
# [1300]	valid_0's l2: 4072.26
# [1350]	valid_0's l2: 4022.96
# [1400]	valid_0's l2: 3977.63
# [1450]	valid_0's l2: 3935.78
# [1500]	valid_0's l2: 3896.87
# [1550]	valid_0's l2: 3863.7
# [1600]	valid_0's l2: 3830.06
# [1650]	valid_0's l2: 3802.72
# [1700]	valid_0's l2: 3775.18
# [1750]	valid_0's l2: 3747.95
# [1800]	valid_0's l2: 3722.42
# [1850]	valid_0's l2: 3699.7
# [1900]	valid_0's l2: 3679.98
# [1950]	valid_0's l2: 3659.54
# [2000]	valid_0's l2: 3639.56
# [2050]	valid_0's l2: 3620.23
# [2100]	valid_0's l2: 3604.37
# [2150]	valid_0's l2: 3587.54
# [2200]	valid_0's l2: 3571.85
# [2250]	valid_0's l2: 3557.85
# [2300]	valid_0's l2: 3545.69
# [2350]	valid_0's l2: 3533.82
# [2400]	valid_0's l2: 3521.15
# [2450]	valid_0's l2: 3510.61
# [2500]	valid_0's l2: 3501.26
# [2550]	valid_0's l2: 3489.44
# [2600]	valid_0's l2: 3481.22
# [2650]	valid_0's l2: 3471.69
# [2700]	valid_0's l2: 3464.7
# [2750]	valid_0's l2: 3457.67
# [2800]	valid_0's l2: 3449.03
# [2850]	valid_0's l2: 3442.43
# [2900]	valid_0's l2: 3433.71
# [2950]	valid_0's l2: 3426.83
# [3000]	valid_0's l2: 3420.07
# [3050]	valid_0's l2: 3413.46
# [3100]	valid_0's l2: 3407.35
# [3150]	valid_0's l2: 3401.06
# [3200]	valid_0's l2: 3394.89
# [3250]	valid_0's l2: 3388.67
# [3300]	valid_0's l2: 3382.23
# [3350]	valid_0's l2: 3377.2
# [3400]	valid_0's l2: 3372.85
# [3450]	valid_0's l2: 3367.73
# [3500]	valid_0's l2: 3364.33
# [3550]	valid_0's l2: 3359.79
# [3600]	valid_0's l2: 3356.32
# [3650]	valid_0's l2: 3352.33
# [3700]	valid_0's l2: 3347.48
# Early stopping, best iteration is:
# [3715]	valid_0's l2: 3346.79
# mean square error is :3346.7921455503865
# max error:341.52249391006694

# %%
print('验证集均方误差...')
ax = lgb.plot_metric(evals_result)
plt.show()

print('画出特征重要度...')
ax = lgb.plot_importance(gbm, max_num_features=70)
plt.show()
# Out:
# 验证集均方误差...
# 画出特征重要度...

# %%
# LGBM给出测试集结果
result = gbm.predict(test)
df_result = pd.DataFrame(columns=['gameDuration'])
df_result['gameDuration'] = result
# df_result.head()
df_result.to_csv('LGBMresult.csv',index=True,index_label='Index')

# %%
# XGBOOST
import xgboost as xgb
data_matrix = xgb.DMatrix(train,label)
xg_reg= xgb.XGBRegressor(
    objective='reg:linear',
    colsample_bytree=0.3,
    learning_rate=0.05,
    max_depth=15,
    num_boost_round=10000,
    alpha=10
)
xg_reg.fit(x_train,y_train)
pred = xg_reg.predict(x_test)
mean_squared_error(pred,y_test)
# Out:
# [16:44:40] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [16:44:40] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:541:
# Parameters: { num_boost_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# 6978.214298959173

# %%
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.05,
                'max_depth': 10, 'alpha': 10}
cv_results = xgb.cv(dtrain=data_matrix, params=params, nfold=3,
                    num_boost_round=5000,early_stopping_rounds=10,metrics="rmse", as_pandas=True)
cv_results.head()
# Out:
# [15:21:57] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [15:21:57] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [15:21:57] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0      1604.829916        1.251112     1604.912191       2.432056
# 1      1525.877116        1.183829     1526.026571       2.261114
# 2      1450.943237        1.197406     1451.223918       2.025414
# 3      1379.706136        1.202765     1380.079916       1.761220
# 4      1312.226969        1.487518     1312.651367       1.270110

# %%
from sklearn.ensemble import RandomForestRegressor
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)
RFR_pred = RFR.predict(x_test)
print(f'mean square error is :{mean_squared_error(y_test,RFR_pred)}')
print(f'max error:{max(abs(np.array(RFR_pred)-np.array(y_test)))}')
# Out:
# mean square error is :8123.016986141667
# max error:672.02
